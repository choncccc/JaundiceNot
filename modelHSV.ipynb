# %% [markdown]
# ## MODEL
# * Install muna ako NVIDIA CUDA tas cuDNN para di sumabog PC

# %%
import os
import time
import numpy as np
import io
import cv2
import pandas as pd
from sklearn.utils import shuffle
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.utils import load_img, img_to_array

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    print("GPUs available:")
    for gpu in gpus:
        print(gpu)
        details = tf.config.experimental.get_device_details(gpu)
        print("GPU Details:", details)
else:
    print("No GPUs available.")
# Out:
# GPUs available:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# GPU Details: {'device_name': 'NVIDIA GeForce RTX 2060', 'compute_capability': (7, 5)}

# %%
def load_images_and_labels(folder, label):
    images = []
    for file in os.listdir(folder):
        image_path = os.path.join(folder, file)
        image = tf.keras.utils.img_to_array(tf.keras.utils.load_img(image_path))
        hsv_image = cv2.cvtColor(image.astype(np.uint8), cv2.COLOR_RGB2HSV)
        hue_channel = hsv_image[:, :, 0]
        images.append(hue_channel.flatten())

    labels = [label] * len(images)
    return np.array(images), np.array(labels)

train_jaundiced_images, train_jaundiced_labels = load_images_and_labels("./new/Jaundiced Class/train", 1)
train_healthy_images, train_healthy_labels = load_images_and_labels("./new/Normal Class/train", 0)

X_train = np.vstack((train_jaundiced_images, train_healthy_images))
y_train = np.hstack((train_jaundiced_labels, train_healthy_labels))

X_train, y_train = shuffle(X_train, y_train, random_state=1)

test_jaundiced_images, test_jaundiced_labels = load_images_and_labels("./new/Jaundiced Class/test", 1)
test_healthy_images, test_healthy_labels = load_images_and_labels("./new/Normal Class/test", 0)

val_jaundiced_images, val_jaundiced_labels = load_images_and_labels("./new/Jaundiced Class/validate", 1)
val_healthy_images, val_healthy_labels = load_images_and_labels("./new/Normal Class/validate", 0)

X_test = np.vstack((test_jaundiced_images, test_healthy_images))
y_test = np.hstack((test_jaundiced_labels, test_healthy_labels))

X_val = np.vstack((val_jaundiced_images, val_healthy_images))
y_val = np.hstack((val_jaundiced_labels, val_healthy_labels))

print("Test data shape:", X_test.shape)
print("Validation data shape:", X_val.shape)
print("Jaundiced images shape:", train_jaundiced_images.shape)
print("Healthy images shape:", train_healthy_images.shape)
print("X_train shape:", X_train.shape)
print("X_train dtype:", X_train.dtype)
print("First 5 rows of X_train:", X_train[:5])
# Out:
# Test data shape: (120, 40000)
# Validation data shape: (245, 40000)
# Jaundiced images shape: (390, 40000)
# Healthy images shape: (457, 40000)
# X_train shape: (847, 40000)
# X_train dtype: uint8
# First 5 rows of X_train: [[14 14 15 ...  6  7  7]
#  [ 9  9  9 ...  0  0  0]
#  [16 16 16 ...  0  0  0]
#  [11 11 11 ... 12 12 12]
#  [11 11 11 ... 10 10 10]]

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("X_val shape:", X_val.shape)
# Out:
# X_train shape: (847, 40000)
# X_test shape: (120, 40000)
# X_val shape: (245, 40000)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  # Fit 
X_test = scaler.transform(X_test)       # Transform test data (images only with no annotations but with features)
X_val = scaler.transform(X_val)

# %%
model = Sequential([
    Dense(512, activation='relu', kernel_regularizer=l2(0.01), input_dim=X_train.shape[1]),  
    BatchNormalization(),
    Dropout(0.2),

    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),  
    BatchNormalization(),
    Dropout(0.2),

    Dense(128, activation='relu', kernel_regularizer=l2(0.005)),  
    BatchNormalization(),
    Dropout(0.2),

    Dense(64, activation='relu', kernel_regularizer=l2(0.005)),  
    BatchNormalization(),
    Dropout(0.1),

    Dense(1, activation='sigmoid')  # Binary classification
])
# Out:
# C:\Users\kenji\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy', Precision()]
)

# Callbacks Early Stopping and Reduce LR on Plateau
early_stopping = EarlyStopping(monitor='val_loss', mode='min', patience=7, restore_best_weights=True)  
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

#Training
start_time = time.time()
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, lr_scheduler]
)

elapsed_time = time.time() - start_time

# Evaluate Model
loss, accuracy, precision = model.evaluate(X_test, y_test)
stopped_epoch = early_stopping.stopped_epoch

print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}, Test Precision: {precision:.4f}")
print(f"Training stopped at Epoch: {stopped_epoch}, Time Taken: {elapsed_time:.2f} sec")
# Out:
# Epoch 1/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 212ms/step - accuracy: 0.6113 - loss: 15.4235 - precision: 0.5954 - val_accuracy: 0.6082 - val_loss: 14.7327 - val_precision: 0.5475 - learning_rate: 5.0000e-04
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.7509 - loss: 13.2437 - precision: 0.7350 - val_accuracy: 0.6571 - val_loss: 11.5532 - val_precision: 0.5829 - learning_rate: 5.0000e-04
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.8202 - loss: 10.5035 - precision: 0.7768 - val_accuracy: 0.7061 - val_loss: 9.2083 - val_precision: 0.6213 - learning_rate: 5.0000e-04
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 204ms/step - accuracy: 0.8461 - loss: 8.5654 - precision: 0.8255 - val_accuracy: 0.7592 - val_loss: 7.6531 - val_precision: 0.7015 - learning_rate: 5.0000e-04
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 233ms/step - accuracy: 0.8531 - loss: 7.2734 - precision: 0.8579 - val_accuracy: 0.8122 - val_loss: 6.6877 - val_precision: 0.8131 - learning_rate: 5.0000e-04
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.8631 - loss: 6.4320 - precision: 0.8323 - val_accuracy: 0.7959 - val_loss: 6.0923 - val_precision: 0.7647 - learning_rate: 5.0000e-04
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.8634 - loss: 5.8221 - precision: 0.8693 - val_accuracy: 0.8000 - val_loss: 5.5646 - val_precision: 0.7857 - learning_rate: 5.0000e-04
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.8948 - loss: 5.2681 - precision: 0.9037 - val_accuracy: 0.7837 - val_loss: 5.1054 - val_precision: 0.7500 - learning_rate: 5.0000e-04
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 214ms/step - accuracy: 0.9169 - loss: 4.8218 - precision: 0.9073 - val_accuracy: 0.7796 - val_loss: 4.7430 - val_precision: 0.7479 - learning_rate: 5.0000e-04
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.9201 - loss: 4.4596 - precision: 0.9157 - val_accuracy: 0.7878 - val_loss: 4.5344 - val_precision: 0.8144 - learning_rate: 5.0000e-04
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.9273 - loss: 4.1785 - precision: 0.9131 - val_accuracy: 0.7959 - val_loss: 4.2661 - val_precision: 0.7203 - learning_rate: 5.0000e-04
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - accuracy: 0.8939 - loss: 4.0210 - precision: 0.8676 - val_accuracy: 0.8000 - val_loss: 4.0664 - val_precision: 0.8265 - learning_rate: 5.0000e-04
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.8899 - loss: 3.8286 - precision: 0.8676 - val_accuracy: 0.7959 - val_loss: 3.8920 - val_precision: 0.7944 - learning_rate: 5.0000e-04
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.9012 - loss: 3.6399 - precision: 0.9053 - val_accuracy: 0.7878 - val_loss: 3.7600 - val_precision: 0.7194 - learning_rate: 5.0000e-04
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 208ms/step - accuracy: 0.8956 - loss: 3.5181 - precision: 0.8781 - val_accuracy: 0.7837 - val_loss: 3.6944 - val_precision: 0.7941 - learning_rate: 5.0000e-04
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9255 - loss: 3.2516 - precision: 0.9290 - val_accuracy: 0.7184 - val_loss: 3.4658 - val_precision: 0.7558 - learning_rate: 5.0000e-04
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.9264 - loss: 2.9891 - precision: 0.9389 - val_accuracy: 0.8082 - val_loss: 3.1738 - val_precision: 0.8056 - learning_rate: 5.0000e-04
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - accuracy: 0.9170 - loss: 2.9395 - precision: 0.9067 - val_accuracy: 0.7714 - val_loss: 3.3850 - val_precision: 0.7879 - learning_rate: 5.0000e-04
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - accuracy: 0.9228 - loss: 3.0772 - precision: 0.8948 - val_accuracy: 0.7469 - val_loss: 3.4241 - val_precision: 0.7179 - learning_rate: 5.0000e-04
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.9016 - loss: 3.1122 - precision: 0.9163 - val_accuracy: 0.7755 - val_loss: 3.1950 - val_precision: 0.7302 - learning_rate: 5.0000e-04
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.9107 - loss: 2.8478 - precision: 0.9058 - val_accuracy: 0.7592 - val_loss: 2.9995 - val_precision: 0.7755 - learning_rate: 2.5000e-04
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 187ms/step - accuracy: 0.9523 - loss: 2.5701 - precision: 0.9424 - val_accuracy: 0.8041 - val_loss: 2.7595 - val_precision: 0.7686 - learning_rate: 2.5000e-04
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.9697 - loss: 2.3238 - precision: 0.9766 - val_accuracy: 0.7755 - val_loss: 2.6073 - val_precision: 0.7377 - learning_rate: 2.5000e-04
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.9604 - loss: 2.1795 - precision: 0.9417 - val_accuracy: 0.7673 - val_loss: 2.5579 - val_precision: 0.7258 - learning_rate: 2.5000e-04
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.9591 - loss: 2.0451 - precision: 0.9560 - val_accuracy: 0.7633 - val_loss: 2.4321 - val_precision: 0.7068 - learning_rate: 2.5000e-04
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9589 - loss: 1.9970 - precision: 0.9398 - val_accuracy: 0.7020 - val_loss: 2.6653 - val_precision: 0.7500 - learning_rate: 2.5000e-04
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9211 - loss: 2.1108 - precision: 0.9252 - val_accuracy: 0.8041 - val_loss: 2.4020 - val_precision: 0.7826 - learning_rate: 2.5000e-04
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 178ms/step - accuracy: 0.9528 - loss: 2.0629 - precision: 0.9524 - val_accuracy: 0.8000 - val_loss: 2.3286 - val_precision: 0.7500 - learning_rate: 2.5000e-04
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9541 - loss: 1.9562 - precision: 0.9382 - val_accuracy: 0.8082 - val_loss: 2.2807 - val_precision: 0.7946 - learning_rate: 2.5000e-04
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step - accuracy: 0.9597 - loss: 1.8662 - precision: 0.9485 - val_accuracy: 0.7714 - val_loss: 2.2879 - val_precision: 0.7395 - learning_rate: 2.5000e-04
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.9262 - loss: 1.9039 - precision: 0.9248 - val_accuracy: 0.7551 - val_loss: 2.4801 - val_precision: 0.6828 - learning_rate: 2.5000e-04
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.9237 - loss: 1.9607 - precision: 0.9060 - val_accuracy: 0.7633 - val_loss: 2.4212 - val_precision: 0.6821 - learning_rate: 2.5000e-04
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.9691 - loss: 1.8478 - precision: 0.9586 - val_accuracy: 0.8041 - val_loss: 2.2675 - val_precision: 0.7481 - learning_rate: 1.2500e-04
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.9686 - loss: 1.7648 - precision: 0.9494 - val_accuracy: 0.7837 - val_loss: 2.2294 - val_precision: 0.7273 - learning_rate: 1.2500e-04
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.9830 - loss: 1.6534 - precision: 0.9834 - val_accuracy: 0.7673 - val_loss: 2.2542 - val_precision: 0.6892 - learning_rate: 1.2500e-04
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.9827 - loss: 1.5926 - precision: 0.9791 - val_accuracy: 0.7878 - val_loss: 2.1228 - val_precision: 0.7194 - learning_rate: 1.2500e-04
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.9753 - loss: 1.5321 - precision: 0.9734 - val_accuracy: 0.7714 - val_loss: 2.1033 - val_precision: 0.7021 - learning_rate: 1.2500e-04
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.9582 - loss: 1.5265 - precision: 0.9664 - val_accuracy: 0.7837 - val_loss: 1.9960 - val_precision: 0.8125 - learning_rate: 1.2500e-04
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.9770 - loss: 1.4706 - precision: 0.9844 - val_accuracy: 0.7755 - val_loss: 2.0326 - val_precision: 0.7164 - learning_rate: 1.2500e-04
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.9654 - loss: 1.4784 - precision: 0.9540 - val_accuracy: 0.7673 - val_loss: 1.9913 - val_precision: 0.7029 - learning_rate: 1.2500e-04
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 196ms/step - accuracy: 0.9413 - loss: 1.5236 - precision: 0.9327 - val_accuracy: 0.7510 - val_loss: 2.0111 - val_precision: 0.6781 - learning_rate: 1.2500e-04
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 0.9746 - loss: 1.4448 - precision: 0.9715 - val_accuracy: 0.8000 - val_loss: 1.9030 - val_precision: 0.7500 - learning_rate: 1.2500e-04
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.9792 - loss: 1.3927 - precision: 0.9658 - val_accuracy: 0.7837 - val_loss: 1.9111 - val_precision: 0.7206 - learning_rate: 1.2500e-04
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.9706 - loss: 1.3793 - precision: 0.9690 - val_accuracy: 0.7755 - val_loss: 1.9218 - val_precision: 0.7302 - learning_rate: 1.2500e-04
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 0.9803 - loss: 1.3303 - precision: 0.9803 - val_accuracy: 0.7837 - val_loss: 1.8950 - val_precision: 0.7778 - learning_rate: 1.2500e-04
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.9775 - loss: 1.3042 - precision: 0.9685 - val_accuracy: 0.7837 - val_loss: 1.9617 - val_precision: 0.7459 - learning_rate: 1.2500e-04
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 203ms/step - accuracy: 0.9783 - loss: 1.2908 - precision: 0.9830 - val_accuracy: 0.7796 - val_loss: 1.8685 - val_precision: 0.7658 - learning_rate: 1.2500e-04
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - accuracy: 0.9772 - loss: 1.2707 - precision: 0.9688 - val_accuracy: 0.7755 - val_loss: 1.8115 - val_precision: 0.7231 - learning_rate: 1.2500e-04
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.9876 - loss: 1.2237 - precision: 0.9799 - val_accuracy: 0.7633 - val_loss: 1.8163 - val_precision: 0.7778 - learning_rate: 1.2500e-04
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.9942 - loss: 1.1923 - precision: 0.9936 - val_accuracy: 0.7796 - val_loss: 1.7898 - val_precision: 0.7864 - learning_rate: 1.2500e-04
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6677 - loss: 2.0290 - precision: 0.8714
# Test Loss: 1.9130, Test Accuracy: 0.7083, Test Precision: 0.7500
# Training stopped at Epoch: 0, Time Taken: 274.29 sec

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")

cm = confusion_matrix(y_test, y_pred)
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Plot CM
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Loss and Accuracy Plots
plt.figure(figsize=(12, 4))

# Loss Plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy Plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.85      0.76        65
#            1       0.75      0.55      0.63        55
#
#     accuracy                           0.71       120
#    macro avg       0.72      0.70      0.70       120
# weighted avg       0.72      0.71      0.70       120

# %%
model.save("Jaundice_ClassifierV1.keras")
